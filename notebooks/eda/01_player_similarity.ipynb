# %% [markdown]
# # Player Similarity — Content-Based Recommendation
#
# Build a FAISS index over each player's calibrated career vector (lifetime
# playstyle stats, surface career performance, and reputation as primary
# signals), then find the
# most similar players for a given player.

# %%
from src.constants import load_env

load_env()
target_player = "carlos alcaraz"
top_k = 5

# %%
from src.training.similarity import PlayerSimilarity

similarity_index = PlayerSimilarity()
similarity_index.build()
# Out:
# Index (153 players) saved to /Users/steve/dev/tennis/tennis-ml/data/processed/player_similarity.index

# %%
similar_players = similarity_index.search(target_player, top_k=top_k)

if not similar_players:
    print(f"Player '{target_player}' not found.")
else:
    print(f"\nPlayers similar to {target_player}:")
    for s in similar_players:
        print(f"  {s['player_id']:12s}  {s['display_name']:25s}  {s['score']}")
# Out:
# Players similar to carlos alcaraz:
#   C0JP          Raphael Collignon          0.945
#   B0BI          Sebastian Baez             0.942
#   MM58          Daniil Medvedev            0.939
#   D643          Novak Djokovic             0.932
#   Z355          Alexander Zverev           0.931
